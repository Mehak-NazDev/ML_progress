# %%
import pandas as pd


print("Real Heart Disease Analysis_kaggle edition")

# loading the dataset

df = pd.read_csv('/kaggle/input/heart-disease-dataset/heart.csv')
print(f" loaded {len(df)} patienyt records with {len(df.columns)} medical features")

#exploring the dataset
print("\n explore the top columns")
print(df.head())

print("\n Basic info:")
print(df.info())

print("DAY 1 completed: We've loaded and understood our real medical dataset!")
# Out:
# Real Heart Disease Analysis_kaggle edition
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       4 print("Real Heart Disease Analysis_kaggle edition")
#       6 # loading the dataset
# ----> 8 df = pd.read_csv('/kaggle/input/heart-disease-dataset/heart.csv')
#       9 print(f" loaded {len(df)} patienyt records with {len(df.columns)} medical features")
#      11 #exploring the dataset
#
# ...

# %%
print("Decoding the medical data:")
print(f"Dataset Shape: {df.shape}")
print("\n Meaning of each column:")
print("age : Patient age in years")
print("sex : 1 = Male, 0 = Female") 
print("cp : Chest pain type (0-3 scale)")
print("trestbps : Resting blood pressure (mm Hg)")
print("chol : Serum cholesterol (mg/dl)")
print("fbs : Fasting blood sugar > 120 mg/dl (1=true, 0=false)")
print("restecg : Resting electrocardiographic results")
print("thalach : Maximum heart rate achieved")
print("exang : Exercise induced angina (1=yes, 0=no)")
print("oldpeak : ST depression induced by exercise")
print("slope : Slope of the peak exercise ST segment")
print("ca : Number of major vessels (0-3) colored by fluoroscopy")
print("thal : Thalassemia (3=normal, 6=fixed defect, 7=reversible defect)")
print("target : Heart disease (0=no, 1=yes)")

print(f"\n Real patient protected identity")
print(f"We're analyzing {len(df)} real people's health data ethically!")
# Out:
# Decoding the medical data:
# Dataset Shape: (1025, 14)
#
#  Meaning of each column:
# age : Patient age in years
# sex : 1 = Male, 0 = Female
# cp : Chest pain type (0-3 scale)
# trestbps : Resting blood pressure (mm Hg)
# chol : Serum cholesterol (mg/dl)
# fbs : Fasting blood sugar > 120 mg/dl (1=true, 0=false)
# restecg : Resting electrocardiographic results
# thalach : Maximum heart rate achieved
# exang : Exercise induced angina (1=yes, 0=no)
# oldpeak : ST depression induced by exercise
# slope : Slope of the peak exercise ST segment
# ca : Number of major vessels (0-3) colored by fluoroscopy
# thal : Thalassemia (3=normal, 6=fixed defect, 7=reversible defect)
# target : Heart disease (0=no, 1=yes)
#
#  Real patient protected identity
# We're analyzing 1025 real people's health data ethically!
